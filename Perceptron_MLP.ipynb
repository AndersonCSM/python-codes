# %% [markdown]
# Este projeto foi concebido no âmbito da disciplina de Inteligência Artificial, com o objetivo de aprofundar o entendimento acerca do funcionamento do Perceptron e do Multi Layer Perceptron - dois componentes essenciais no domínio das redes neurais.
#
# Neste projeto, são abordados a implementação do Perceptron para compreender seu funcionamento, englobando inclusive a inclusão do viés, para tratar de **problemas logicamente separáveis.** Adicionalmente, temos a aplicação do Multi Layer Perceptron, configurado com uma **única camada oculta**, demonstrando sua capacidade de solucionar o desafio apresentado pelo **operador lógico XOR.**
#
# <div style="text-align: right;">Colaboradores:</div>
# <div style="text-align: right;">Anderson Carlos da Silva Morais</div>
# <div style="text-align: right;">Anderson Matheus Melo da Silva</div>

# %% [markdown]
# # Perceptron
# O Perceptron é um dos blocos fundamentais na área de redes neurais artificiais. Ele é um modelo simples de neurônio artificial que recebe entradas ponderadas, aplica uma função de ativação e produz uma saída binária (0 ou 1)

# %%
# Biblioteca matemática
import numpy as np


# Função de ativação Step Function
def Step(x):
    if x >= 0:
        return 1
    else:
        return 0

# %%
def train_perceptron(X, Y, taxa_apren, iteracoes, peso_ini=0.1, vies=1):
    # Pré-configuração
    linhas = X.shape[0]  # Quantidade de linhas
    colunas = X.shape[1]  # Quantidade de colunas
    np.random.seed(42)  # Definindo a seed dos números aleatórios

    # Para um uso futuro com métricas
    rede = []  # valores da rede
    y_preds = []  # valores das predições
    erros = []  # valores dos erros

    # Pesos
    if peso_ini == 0.1:
        # O tamanho é igual das colunas para podermos realizar multiplicação de matrizes
        pesos = np.full(colunas, peso_ini)  # Cria o array de pesos com o valor peso_ini
        peso_vies = 0.1  # peso do vies definido como o peso_ini

    else:
        # O tamanho é igual das colunas para podermos realizar multiplicação de matrizes
        pesos = np.random.uniform(
            size=colunas
        )  # Cria o array de pesos com o valor aleatório
        peso_vies = np.random.uniform()  # peso do vies definido como aleatório

    # Treinamento do perceptron
    for _ in range(iteracoes):
        for i in range(linhas):  # percorrea quantidade de linhas
            # rede
            soma_rede = np.dot(X[i], pesos) + (vies * peso_vies)
            rede.append(soma_rede)

            # activation
            y_pred = Step(soma_rede)
            y_preds.append(y_pred)

            # erro
            erro = Y[i] - y_pred
            erros.append(erro)

            # novos pesos
            for k in range(colunas):  # percorre a quantidade de colunas
                pesos[k] = pesos[k] + taxa_apren * erro * X[i, k]

            peso_vies = peso_vies + taxa_apren * erro * vies

    return pesos, vies, peso_vies


# Função para realizar predições de valores
def predict(entrada, pesos, vies, peso_vies):
    predict = np.dot(entrada, pesos) + vies * peso_vies
    return Step(predict)

# %%
# Entrada
X = np.array([[20, 10], [80, 60], [-20, 10], [20, 10]])
Y = np.array([0, 1, 1, 0])

# treinando o perceptron para achar os valores treinados
pesos_train, vies_train, peso_vies_train = train_perceptron(X, Y, 0.1, 5)

# fazendo um predict para valores aleatórios
teste = predict([0, 10], pesos_train, vies_train, peso_vies_train)

# printando na tela
print(teste)
# Out:
# 1

# %%
# Testando valores diferentes
teste = predict([50, 30], pesos_train, vies_train, peso_vies_train)

print(teste)
# Out:
# 0

# %% [markdown]
# # OPERADORES LÓGICOS
# ## AND

# %%
# Entrada
X = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y = np.array([1, 0, 0, 0])

# treinando o perceptron para achar os valores treinados
pesos_train, vies_train, peso_vies_train = train_perceptron(X, Y, 0.1, 5)

# %%
# Testando valores diferentes
teste = predict([1, 1], pesos_train, vies_train, peso_vies_train)

print(teste)
# Out:
# 1

# %% [markdown]
# ## OR

# %%
# Entrada
X = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y = np.array([1, 1, 1, 0])

# treinando o perceptron para achar os valores treinados
pesos_train, vies_train, peso_vies_train = train_perceptron(X, Y, 0.1, 5)

# %%
# Testando valores diferentes
teste = predict([1, 0], pesos_train, vies_train, peso_vies_train)

print(teste)
# Out:
# 1

# %% [markdown]
# ## XOR

# %%
# Entrada
X = np.array([[1, 1], [1, 0], [0, 1], [0, 0]])
Y = np.array([0, 1, 1, 0])

# treinando o perceptron para achar os valores treinados
pesos_train, vies_train, peso_vies_train = train_perceptron(X, Y, 0.1, 5)

# %%
# Testando valores diferentes
teste = predict([0, 0], pesos_train, vies_train, peso_vies_train)

print(teste)
# Out:
# 0

# %% [markdown]
# Não resolveu, partimos para uma rede MLP

# %% [markdown]
# # MULTI LAYER PERCEPTRON(MLP)
# O MLP é uma extensão do conceito de Perceptron. Ele consiste em várias camadas de neurônios, incluindo uma camada de entrada, uma ou mais camadas ocultas e uma camada de saída. Cada neurônio em uma camada está conectado a todos os neurônios na camada seguinte. O MLP é capaz de lidar com problemas mais complexos, uma vez que pode aprender representações hierárquicas de dados através das camadas ocultas.
#
# As camadas ocultas do MLP usam funções de ativação não-lineares, como a função sigmoide, ReLU (Rectified Linear Unit) ou suas variantes, para introduzir não-linearidades nas transformações dos dados. Isso permite que o MLP capture relações complexas entre as entradas e as saídas, tornando-o um modelo poderoso para tarefas de aprendizado supervisionado, como classificação e regressão.

# %%
import numpy as np


# Funcao de ativacao sigmoidal
def sigmoide(x):
    return 1 / (1 + np.exp(-x))


# Derivada da funcao sigmoidal
def derivada_sigmoide(x):
    return x * (1 - x)

# %%
def train_mlp(
    X,
    Y,
    neuronios=2,
    taxa_aprendizado=0.1,
    iteracoes=2,
    peso_ini=True,
    vies=1,
    error=True,
):
    # Pré-configuração
    X_size = X.shape[1]  # Quantidade de linhas
    Y_size = Y.shape[1]  # Quantidade de colunas
    np.random.seed(42)  # Definindo a seed dos números aleatórios

    # Ordem neuronio: OBS: foi a única forma que eu consegui racionacionar o funcionamento
    # Entrada -> Oculta -> Saida
    # Entrada -> (característica em comum)
    # Oculta -> (característica em comum)
    # Peso_Entrada -> Peso_Oculta

    # Pesos
    if peso_ini:
        peso_entrada = np.full((X_size, neuronios), 0.1)
        peso_oculta = np.full((neuronios, Y_size), 0.1)
    else:
        # Passo 0: inicializa os pesos
        peso_entrada = np.random.uniform(size=(X_size, neuronios))
        # os pesos da entrada será uma matriz de linhas iguais as colunas da entrada e com colunas iguais as quantidades de neuronios
        peso_oculta = np.random.uniform(size=(neuronios, Y_size))
        # os pesos da oculta será uma matriz com as linhas na quantidade de neuronios e colunas igual ao tamanho da saida
        # Basicamente associando matriz de pesos dimensionalmente coerentes para multiplicá-las

    # Treinamento do perceptron
    for _ in range(iteracoes):
        erro_tot = 0  # Variável de controle para observar o erro
        for i in range(len(X)):  # percorrea quantidade de linhas de características
            # Trabalhando elemento a elemento da matriz
            # Passo 1: Vetores de entrada
            x_entrada = X[i]
            y_saida = Y[i]

            # Feedforward
            # Entrada -> Oculta -> Saida
            #      y_Entrada   y_Saida

            # rede Entrada
            # Passo 2 e 3:
            sum_entrada = np.dot(x_entrada, peso_entrada)
            y_entrada = sigmoide(sum_entrada)

            # rede Oculta
            # passo 4 e 5:
            sum_oculta = np.dot(y_entrada, peso_oculta)
            y_oculta = sigmoide(sum_oculta)

            # erro
            erro = y_saida - y_oculta  # erro: (dk - Ok)
            erro_tot += np.mean(np.square(erro))  # MSE

            # Backpropagation
            # Saida -> Oculta -> Entrada
            # Ajustes em:
            #  y_oculta -> y_Entrada

            # Camada saida
            # passo 6:
            delta_oculta = erro * derivada_sigmoide(
                y_oculta
            )  # Derivada: y_oculta * (1 - y_oculta)
            ajuste_oculta = taxa_aprendizado * np.outer(
                y_entrada, delta_oculta
            )  # outer:[ndarray] Returns the outer product of two vectors. out[i, j] = y_entrada[i] * delta_oculta[j]

            # Camada_Entrada
            # passo 7:
            erro_entrada = (
                delta_oculta @ peso_oculta.T
            )  # Multiplicação de matrizes, resultando em uma matriz
            delta_entrada = erro_entrada * derivada_sigmoide(
                y_entrada
            )  # Derivada: y_entrada * (1 - y_entrada)
            ajuste_entrada = taxa_aprendizado * np.outer(
                x_entrada, delta_entrada
            )  # outer:[ndarray] Returns the outer product of two vectors. out[i, j] = x_entrada[i] * delta_entrada[j]

            # novos pesos
            # passo 8 e 9:
            peso_entrada += ajuste_entrada
            peso_oculta += ajuste_oculta

        # Passo 10:
        erro_medio = erro_tot / len(X)

        if error:
            print(f"Iteracao {_+1}, Erro Médio: {erro_medio:.6f}")

    return peso_entrada, peso_oculta

# %%
# Função para realizar predições de valores
def predict_XOR(X, peso_entrada, peso_oculta):
    for i in range(len(X)):
        # Feedforward

        entrada_oculta = np.dot(X[i], peso_entrada)
        y_entrada = sigmoide(entrada_oculta)

        sum_oculta = np.dot(y_entrada, peso_oculta)
        y_pred = sigmoide(sum_oculta)
    return y_pred

# %%
# Dados de entrada e saida para o problema do XOR
X = np.array([[1, 0], [1, 1], [0, 0], [0, 1]])
Y = np.array([[1], [0], [0], [1]])

# Treinamento
peso_entrada, peso_oculta = train_mlp(
    X, Y, taxa_aprendizado=0.3, neuronios=2, iteracoes=30000, peso_ini=False, error=True
)
# Out:
# Iteracao 1, Erro Médio: 0.256037
# Iteracao 2, Erro Médio: 0.255808
# Iteracao 3, Erro Médio: 0.255606
# Iteracao 4, Erro Médio: 0.255427
# Iteracao 5, Erro Médio: 0.255269
# Iteracao 6, Erro Médio: 0.255129
# Iteracao 7, Erro Médio: 0.255006
# Iteracao 8, Erro Médio: 0.254897
# Iteracao 9, Erro Médio: 0.254801
# Iteracao 10, Erro Médio: 0.254716
# Iteracao 11, Erro Médio: 0.254641
# Iteracao 12, Erro Médio: 0.254575
# Iteracao 13, Erro Médio: 0.254517
# Iteracao 14, Erro Médio: 0.254466
# Iteracao 15, Erro Médio: 0.254420
# Iteracao 16, Erro Médio: 0.254380
# Iteracao 17, Erro Médio: 0.254345
# Iteracao 18, Erro Médio: 0.254314
# Iteracao 19, Erro Médio: 0.254286
# Iteracao 20, Erro Médio: 0.254262
# Iteracao 21, Erro Médio: 0.254240
# Iteracao 22, Erro Médio: 0.254221
# Iteracao 23, Erro Médio: 0.254204
# Iteracao 24, Erro Médio: 0.254189
# Iteracao 25, Erro Médio: 0.254176
# Iteracao 26, Erro Médio: 0.254164
# Iteracao 27, Erro Médio: 0.254154
# Iteracao 28, Erro Médio: 0.254144
# Iteracao 29, Erro Médio: 0.254136
# Iteracao 30, Erro Médio: 0.254129
# Iteracao 31, Erro Médio: 0.254122
# Iteracao 32, Erro Médio: 0.254116
# Iteracao 33, Erro Médio: 0.254111
# Iteracao 34, Erro Médio: 0.254106
# Iteracao 35, Erro Médio: 0.254101
# Iteracao 36, Erro Médio: 0.254097
# Iteracao 37, Erro Médio: 0.254094
# Iteracao 38, Erro Médio: 0.254090
# Iteracao 39, Erro Médio: 0.254087
# Iteracao 40, Erro Médio: 0.254084
# Iteracao 41, Erro Médio: 0.254082
# Iteracao 42, Erro Médio: 0.254079
# Iteracao 43, Erro Médio: 0.254077
# Iteracao 44, Erro Médio: 0.254075
# Iteracao 45, Erro Médio: 0.254073
# Iteracao 46, Erro Médio: 0.254071
# Iteracao 47, Erro Médio: 0.254069
# Iteracao 48, Erro Médio: 0.254068
# Iteracao 49, Erro Médio: 0.254066
# Iteracao 50, Erro Médio: 0.254065
# Iteracao 51, Erro Médio: 0.254063
# Iteracao 52, Erro Médio: 0.254062
# Iteracao 53, Erro Médio: 0.254060
# Iteracao 54, Erro Médio: 0.254059
# Iteracao 55, Erro Médio: 0.254058
# Iteracao 56, Erro Médio: 0.254056
# Iteracao 57, Erro Médio: 0.254055
# Iteracao 58, Erro Médio: 0.254054
# Iteracao 59, Erro Médio: 0.254052
# Iteracao 60, Erro Médio: 0.254051
# Iteracao 61, Erro Médio: 0.254050
# Iteracao 62, Erro Médio: 0.254049
# Iteracao 63, Erro Médio: 0.254048
# Iteracao 64, Erro Médio: 0.254046
# Iteracao 65, Erro Médio: 0.254045
# Iteracao 66, Erro Médio: 0.254044
# Iteracao 67, Erro Médio: 0.254043
# Iteracao 68, Erro Médio: 0.254042
# Iteracao 69, Erro Médio: 0.254041
# Iteracao 70, Erro Médio: 0.254040
# Iteracao 71, Erro Médio: 0.254038
# Iteracao 72, Erro Médio: 0.254037
# Iteracao 73, Erro Médio: 0.254036
# Iteracao 74, Erro Médio: 0.254035
# Iteracao 75, Erro Médio: 0.254034
# Iteracao 76, Erro Médio: 0.254033
# Iteracao 77, Erro Médio: 0.254032
# Iteracao 78, Erro Médio: 0.254031
# Iteracao 79, Erro Médio: 0.254029
# Iteracao 80, Erro Médio: 0.254028
# Iteracao 81, Erro Médio: 0.254027
# Iteracao 82, Erro Médio: 0.254026
# Iteracao 83, Erro Médio: 0.254025
# Iteracao 84, Erro Médio: 0.254024
# Iteracao 85, Erro Médio: 0.254023
# Iteracao 86, Erro Médio: 0.254022
# Iteracao 87, Erro Médio: 0.254021
# Iteracao 88, Erro Médio: 0.254019
# Iteracao 89, Erro Médio: 0.254018
# Iteracao 90, Erro Médio: 0.254017
# Iteracao 91, Erro Médio: 0.254016
# Iteracao 92, Erro Médio: 0.254015
# Iteracao 93, Erro Médio: 0.254014
# Iteracao 94, Erro Médio: 0.254013
# Iteracao 95, Erro Médio: 0.254012
# Iteracao 96, Erro Médio: 0.254011
# Iteracao 97, Erro Médio: 0.254010
# Iteracao 98, Erro Médio: 0.254008
# Iteracao 99, Erro Médio: 0.254007
# Iteracao 100, Erro Médio: 0.254006
# Iteracao 101, Erro Médio: 0.254005
# Iteracao 102, Erro Médio: 0.254004
# Iteracao 103, Erro Médio: 0.254003
# Iteracao 104, Erro Médio: 0.254002
# Iteracao 105, Erro Médio: 0.254001
# Iteracao 106, Erro Médio: 0.254000
# Iteracao 107, Erro Médio: 0.253998
# Iteracao 108, Erro Médio: 0.253997
# Iteracao 109, Erro Médio: 0.253996
# Iteracao 110, Erro Médio: 0.253995
# Iteracao 111, Erro Médio: 0.253994
# Iteracao 112, Erro Médio: 0.253993
# Iteracao 113, Erro Médio: 0.253992
# Iteracao 114, Erro Médio: 0.253991
# Iteracao 115, Erro Médio: 0.253990
# Iteracao 116, Erro Médio: 0.253988
# Iteracao 117, Erro Médio: 0.253987
# Iteracao 118, Erro Médio: 0.253986
# Iteracao 119, Erro Médio: 0.253985
# Iteracao 120, Erro Médio: 0.253984
# Iteracao 121, Erro Médio: 0.253983
# Iteracao 122, Erro Médio: 0.253982
# Iteracao 123, Erro Médio: 0.253981
# Iteracao 124, Erro Médio: 0.253980
# Iteracao 125, Erro Médio: 0.253979
# Iteracao 126, Erro Médio: 0.253977
# Iteracao 127, Erro Médio: 0.253976
# Iteracao 128, Erro Médio: 0.253975
# Iteracao 129, Erro Médio: 0.253974
# Iteracao 130, Erro Médio: 0.253973
# Iteracao 131, Erro Médio: 0.253972
# Iteracao 132, Erro Médio: 0.253971
# Iteracao 133, Erro Médio: 0.253970
# Iteracao 134, Erro Médio: 0.253969
# Iteracao 135, Erro Médio: 0.253967
# Iteracao 136, Erro Médio: 0.253966
# Iteracao 137, Erro Médio: 0.253965
# Iteracao 138, Erro Médio: 0.253964
# Iteracao 139, Erro Médio: 0.253963
# Iteracao 140, Erro Médio: 0.253962
# Iteracao 141, Erro Médio: 0.253961
# Iteracao 142, Erro Médio: 0.253960
# Iteracao 143, Erro Médio: 0.253959
# Iteracao 144, Erro Médio: 0.253957
# Iteracao 145, Erro Médio: 0.253956
# Iteracao 146, Erro Médio: 0.253955
# Iteracao 147, Erro Médio: 0.253954
# Iteracao 148, Erro Médio: 0.253953
# Iteracao 149, Erro Médio: 0.253952
# Iteracao 150, Erro Médio: 0.253951
# Iteracao 151, Erro Médio: 0.253950
# Iteracao 152, Erro Médio: 0.253949
# Iteracao 153, Erro Médio: 0.253947
# Iteracao 154, Erro Médio: 0.253946
# Iteracao 155, Erro Médio: 0.253945
# Iteracao 156, Erro Médio: 0.253944
# Iteracao 157, Erro Médio: 0.253943
# Iteracao 158, Erro Médio: 0.253942
# Iteracao 159, Erro Médio: 0.253941
# Iteracao 160, Erro Médio: 0.253940
# Iteracao 161, Erro Médio: 0.253939
# Iteracao 162, Erro Médio: 0.253937
# Iteracao 163, Erro Médio: 0.253936
# Iteracao 164, Erro Médio: 0.253935
# Iteracao 165, Erro Médio: 0.253934
# Iteracao 166, Erro Médio: 0.253933
# Iteracao 167, Erro Médio: 0.253932
# Iteracao 168, Erro Médio: 0.253931
# Iteracao 169, Erro Médio: 0.253930
# Iteracao 170, Erro Médio: 0.253928
# Iteracao 171, Erro Médio: 0.253927
# Iteracao 172, Erro Médio: 0.253926
# Iteracao 173, Erro Médio: 0.253925
# Iteracao 174, Erro Médio: 0.253924
# Iteracao 175, Erro Médio: 0.253923
# Iteracao 176, Erro Médio: 0.253922
# Iteracao 177, Erro Médio: 0.253921
# Iteracao 178, Erro Médio: 0.253919
# Iteracao 179, Erro Médio: 0.253918
# Iteracao 180, Erro Médio: 0.253917
# Iteracao 181, Erro Médio: 0.253916
# Iteracao 182, Erro Médio: 0.253915
# Iteracao 183, Erro Médio: 0.253914
# Iteracao 184, Erro Médio: 0.253913
# Iteracao 185, Erro Médio: 0.253912
# Iteracao 186, Erro Médio: 0.253910
# Iteracao 187, Erro Médio: 0.253909
# Iteracao 188, Erro Médio: 0.253908
# Iteracao 189, Erro Médio: 0.253907
# Iteracao 190, Erro Médio: 0.253906
# Iteracao 191, Erro Médio: 0.253905
# Iteracao 192, Erro Médio: 0.253904
# Iteracao 193, Erro Médio: 0.253902
# Iteracao 194, Erro Médio: 0.253901
# Iteracao 195, Erro Médio: 0.253900
# Iteracao 196, Erro Médio: 0.253899
# Iteracao 197, Erro Médio: 0.253898
# Iteracao 198, Erro Médio: 0.253897
# Iteracao 199, Erro Médio: 0.253896
# Iteracao 200, Erro Médio: 0.253895
# Iteracao 201, Erro Médio: 0.253893
# Iteracao 202, Erro Médio: 0.253892
# Iteracao 203, Erro Médio: 0.253891
# Iteracao 204, Erro Médio: 0.253890
# Iteracao 205, Erro Médio: 0.253889
# Iteracao 206, Erro Médio: 0.253888
# Iteracao 207, Erro Médio: 0.253887
# Iteracao 208, Erro Médio: 0.253885
# Iteracao 209, Erro Médio: 0.253884
# Iteracao 210, Erro Médio: 0.253883
# Iteracao 211, Erro Médio: 0.253882
# Iteracao 212, Erro Médio: 0.253881
# Iteracao 213, Erro Médio: 0.253880
# Iteracao 214, Erro Médio: 0.253878
# Iteracao 215, Erro Médio: 0.253877
# Iteracao 216, Erro Médio: 0.253876
# Iteracao 217, Erro Médio: 0.253875
# Iteracao 218, Erro Médio: 0.253874
# Iteracao 219, Erro Médio: 0.253873
# Iteracao 220, Erro Médio: 0.253872
# Iteracao 221, Erro Médio: 0.253870
# Iteracao 222, Erro Médio: 0.253869
# Iteracao 1001, Erro Médio: 0.250341
# Iteracao 1002, Erro Médio: 0.250322
# Iteracao 1003, Erro Médio: 0.250302
# Iteracao 1004, Erro Médio: 0.250282
# Iteracao 1005, Erro Médio: 0.250262
# Iteracao 1006, Erro Médio: 0.250242
# Iteracao 1007, Erro Médio: 0.250222
# Iteracao 1008, Erro Médio: 0.250201
# Iteracao 1009, Erro Médio: 0.250181
# Iteracao 1010, Erro Médio: 0.250160
# Iteracao 1011, Erro Médio: 0.250139
# Iteracao 1012, Erro Médio: 0.250118
# Iteracao 1013, Erro Médio: 0.250097
# Iteracao 1014, Erro Médio: 0.250076
# Iteracao 1015, Erro Médio: 0.250055
# Iteracao 1016, Erro Médio: 0.250033
# Iteracao 1017, Erro Médio: 0.250012
# Iteracao 1018, Erro Médio: 0.249990
# Iteracao 1019, Erro Médio: 0.249968
# Iteracao 1020, Erro Médio: 0.249946
# Iteracao 1021, Erro Médio: 0.249924
# Iteracao 1022, Erro Médio: 0.249902
# Iteracao 1023, Erro Médio: 0.249879
# Iteracao 1024, Erro Médio: 0.249857
# Iteracao 1025, Erro Médio: 0.249834
# Iteracao 1026, Erro Médio: 0.249811
# Iteracao 1027, Erro Médio: 0.249788
# Iteracao 1028, Erro Médio: 0.249765
# Iteracao 1029, Erro Médio: 0.249741
# Iteracao 1030, Erro Médio: 0.249718
# Iteracao 1031, Erro Médio: 0.249694
# Iteracao 1032, Erro Médio: 0.249671
# Iteracao 1033, Erro Médio: 0.249647
# Iteracao 1034, Erro Médio: 0.249623
# Iteracao 1035, Erro Médio: 0.249598
# Iteracao 1036, Erro Médio: 0.249574
# Iteracao 1037, Erro Médio: 0.249549
# Iteracao 1038, Erro Médio: 0.249525
# Iteracao 1039, Erro Médio: 0.249500
# Iteracao 1040, Erro Médio: 0.249475
# Iteracao 1041, Erro Médio: 0.249450
# Iteracao 1042, Erro Médio: 0.249424
# Iteracao 1043, Erro Médio: 0.249399
# Iteracao 1044, Erro Médio: 0.249373
# Iteracao 1045, Erro Médio: 0.249347
# Iteracao 1046, Erro Médio: 0.249321
# Iteracao 1047, Erro Médio: 0.249295
# Iteracao 1048, Erro Médio: 0.249269
# Iteracao 1049, Erro Médio: 0.249243
# Iteracao 1050, Erro Médio: 0.249216
# Iteracao 1051, Erro Médio: 0.249189
# Iteracao 1052, Erro Médio: 0.249162
# Iteracao 1053, Erro Médio: 0.249135
# Iteracao 1054, Erro Médio: 0.249108
# Iteracao 1055, Erro Médio: 0.249080
# Iteracao 1056, Erro Médio: 0.249053
# Iteracao 1057, Erro Médio: 0.249025
# Iteracao 1058, Erro Médio: 0.248997
# Iteracao 1059, Erro Médio: 0.248969
# Iteracao 1060, Erro Médio: 0.248940
# Iteracao 1061, Erro Médio: 0.248912
# Iteracao 1062, Erro Médio: 0.248883
# Iteracao 1063, Erro Médio: 0.248854
# Iteracao 1064, Erro Médio: 0.248825
# Iteracao 1065, Erro Médio: 0.248796
# Iteracao 1066, Erro Médio: 0.248767
# Iteracao 1067, Erro Médio: 0.248737
# Iteracao 29949, Erro Médio: 0.005409
# Iteracao 29950, Erro Médio: 0.005409
# Iteracao 29951, Erro Médio: 0.005408
# Iteracao 29952, Erro Médio: 0.005408
# Iteracao 29953, Erro Médio: 0.005408
# Iteracao 29954, Erro Médio: 0.005408
# Iteracao 29955, Erro Médio: 0.005408
# Iteracao 29956, Erro Médio: 0.005407
# Iteracao 29957, Erro Médio: 0.005407
# Iteracao 29958, Erro Médio: 0.005407
# Iteracao 29959, Erro Médio: 0.005407
# Iteracao 29960, Erro Médio: 0.005406
# Iteracao 29961, Erro Médio: 0.005406
# Iteracao 29962, Erro Médio: 0.005406
# Iteracao 29963, Erro Médio: 0.005406
# Iteracao 29964, Erro Médio: 0.005406
# Iteracao 29965, Erro Médio: 0.005405
# Iteracao 29966, Erro Médio: 0.005405
# Iteracao 29967, Erro Médio: 0.005405
# Iteracao 29968, Erro Médio: 0.005405
# Iteracao 29969, Erro Médio: 0.005405
# Iteracao 29970, Erro Médio: 0.005404
# Iteracao 29971, Erro Médio: 0.005404
# Iteracao 29972, Erro Médio: 0.005404
# Iteracao 29973, Erro Médio: 0.005404
# Iteracao 29974, Erro Médio: 0.005403
# Iteracao 29975, Erro Médio: 0.005403
# Iteracao 29976, Erro Médio: 0.005403
# Iteracao 29977, Erro Médio: 0.005403
# Iteracao 29978, Erro Médio: 0.005403
# Iteracao 29979, Erro Médio: 0.005402
# Iteracao 29980, Erro Médio: 0.005402
# Iteracao 29981, Erro Médio: 0.005402
# Iteracao 29982, Erro Médio: 0.005402
# Iteracao 29983, Erro Médio: 0.005402
# Iteracao 29984, Erro Médio: 0.005401
# Iteracao 29985, Erro Médio: 0.005401
# Iteracao 29986, Erro Médio: 0.005401
# Iteracao 29987, Erro Médio: 0.005401
# Iteracao 29988, Erro Médio: 0.005400
# Iteracao 29989, Erro Médio: 0.005400
# Iteracao 29990, Erro Médio: 0.005400
# Iteracao 29991, Erro Médio: 0.005400
# Iteracao 29992, Erro Médio: 0.005400
# Iteracao 29993, Erro Médio: 0.005399
# Iteracao 29994, Erro Médio: 0.005399
# Iteracao 29995, Erro Médio: 0.005399
# Iteracao 29996, Erro Médio: 0.005399
# Iteracao 29997, Erro Médio: 0.005399
# Iteracao 29998, Erro Médio: 0.005398
# Iteracao 29999, Erro Médio: 0.005398
# Iteracao 30000, Erro Médio: 0.005398

# %%
# Testando valores pro problema do XOR
res = predict_XOR([[0, 0]], peso_entrada, peso_oculta)
print(f"exato:{res} aproximado:{np.round(res)}")
# Out:
# exato:[0.0352327] aproximado:[0.]

# %%
res = predict_XOR([[0, 1]], peso_entrada, peso_oculta)
print(f"exato:{res} aproximado:{np.round(res)}")
# Out:
# exato:[0.93108513] aproximado:[1.]

# %%
res = predict_XOR([[1, 0]], peso_entrada, peso_oculta)
print(f"exato:{res} aproximado:{np.round(res)}")
# Out:
# exato:[0.9266209] aproximado:[1.]

# %%
res = predict_XOR([[1, 1]], peso_entrada, peso_oculta)
print(f"exato:{res} aproximado:{np.round(res)}")
# Out:
# exato:[0.09443881] aproximado:[0.]
